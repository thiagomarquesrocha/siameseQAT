# %% [markdown]
# # Bug triage with Deep Learning - Fasttext

# %%
from __future__ import print_function, division

# %%
import fasttext
import re
import numpy as np
import pandas as pd

import os
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
    
# %matplotlib inline

# %%
from methods.baseline import Baseline
from methods.experiments import Experiment
from methods.evaluation import Evaluation
from methods.retrieval import Retrieval
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Configurações Globais

# %%
MAX_SEQUENCE_LENGTH_T = 100 # 40
MAX_SEQUENCE_LENGTH_D = 500 # 200
EMBEDDING_DIM = 300
MAX_NB_WORDS = 20000

# %% [markdown]
# ### Parse bugs preproprecessed

# %%
# Domain to use
DOMAIN = 'openoffice'
METHOD = 'fasttext'
# Dataset paths
DIR = 'data/processed/{}'.format(DOMAIN)
DIR_PAIRS = 'data/normalized/{}'.format(DOMAIN)
DATASET = os.path.join('data/normalized/{}'.format(DOMAIN), '{}.csv'.format(DOMAIN))
# Path embeddings
EMBED_DIR='data/embed'
# Save model
SAVE_PATH_FEATURE = '{}_feature_@number_of_epochs@epochs({})'.format(METHOD, DOMAIN)

# Test bugs
PATH_TEST = 'data/processed/{}/test.txt'.format(DOMAIN)

# Extract CORPUs
EXTRACT_CORPUS = False

# %% [markdown]
# ## Auxiliary methods

# %%
baseline = Baseline(DIR, DATASET, MAX_SEQUENCE_LENGTH_T, MAX_SEQUENCE_LENGTH_D)
evaluation = Evaluation(verbose=0)
retrieval = Retrieval()
experiment = Experiment(baseline, evaluation)

# %% [markdown]
# #### Creating buckets and initialize the retrieval method

# %%
experiment.set_retrieval(retrieval, baseline, DOMAIN)
# Out:
# Creating the buckets...
# HBox(children=(IntProgress(value=0, max=57667), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=14567), HTML(value='')))

# %% [markdown]
# #### Loading bug ids in memory

# %%
experiment.load_ids()
len(baseline.bug_ids)
# Out:
# Reading bug ids
# 72234

# %% [markdown]
# #### Dicionário de títulos e descrições

# %%
# %%time

experiment.load_bugs()
len(baseline.sentence_dict)
# Out:
# HBox(children=(IntProgress(value=0, max=72234), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# CPU times: user 26.5 s, sys: 999 ms, total: 27.5 s
# Wall time: 26.9 s

# %% [markdown]
# #### Get buckets for each issue

# %%
verbose = 0
issues_by_buckets = experiment.get_buckets_for_bugs()
# Out:
# HBox(children=(IntProgress(value=0, max=58572), HTML(value='')))

# %% [markdown]
# #### Prepare dataset

# %%
experiment.prepare_dataset(issues_by_buckets, path_train='train_chronological', path_test='test_chronological')
# Out:
# Reading train data
# Reading bug ids

# %% [markdown]
# #### Creating the queries to test

# %%
# Read and create the test queries duplicate
experiment.create_queries()
# Out:
# Reading queries from baseline.

# %% [markdown]
# #### Bugs train

# %%
bugs_train_ids = []
for bugs in experiment.baseline.train_data:
    bugs_train_ids.append(bugs[0])
    bugs_train_ids.append(bugs[1])

# %% [markdown]
# #### Corpus

# %%
lines_title = [baseline.bug_set[bug_id]['title'] for bug_id in bugs_train_ids]
lines_desc = [baseline.bug_set[bug_id]['description'] for bug_id in bugs_train_ids]

lines = []
for title, desc in zip(lines_title, lines_desc):
    lines.append(title)
    lines.append(desc)

# %%
len(lines)
# Out:
# 194300

# %% [markdown]
# #### Exporting corpus to .txt

# %%
EXPORT_PATH = os.path.join(DIR, 'corpus_fasttext_train.txt')
print(EXPORT_PATH)
with open(EXPORT_PATH, 'w') as f:
    for row in lines:
        f.write("{}\n".format(str(row).encode("utf-8")))
# Out:
# data/processed/openoffice/corpus_fasttext_train.txt

# %% [markdown]
# #### Train the method

# %%
# %%time

import os

cpu = os.cpu_count() - 1

max_epochs = 15

# Skipgram model :
model = fasttext.train_unsupervised(EXPORT_PATH, 
                                    model='cbow', 
                                    minCount=1,
                                    neg=5,
                                    wordNgrams=3,
                                    epoch=max_epochs, 
                                    dim=300, 
                                    loss='hs', 
                                    thread=cpu, 
                                    verbose=2)
# Out:
# CPU times: user 1h 10min 59s, sys: 5.32 s, total: 1h 11min 5s
# Wall time: 10min 15s

# %% [markdown]
# #### Rank@25

# %%
bug_train_ids = experiment.get_train_ids(baseline.train_data)

# %%
recall, exported_rank, debug = experiment.evaluate_validation_test(retrieval, verbose, model, issues_by_buckets, 
                                                            bug_train_ids, method=METHOD)
"recall@25 last epoch:", recall
# Out:
# ('recall@25 last epoch:', 0.49)

# %% [markdown]
# ### Retrieval evaluation

# %%
print("Total of queries:", len(retrieval.test))
# Out:
# Total of queries: 2086

#  '110604:110612|103572:0.34102046489715576,105337:0.32417815923690796,121629:0.3043200373649597,103575:0.2935737371444702,105991:0.2879968285560608,120996:0.27944105863571167,92290:0.2648088335990906,109972:0.2557998299598694,118884:0.2507093548774719,98664:0.24537795782089233,115767:0.23734480142593384,90306:0.23575574159622192,121807:0.23474711179733276,109862:0.23269915580749512,98302:0.232405424118042,68248:0.23028570413589478,92926:0.23018622398376465,117201:0.22956669330596924,105671:0.22327744960784912,103188:0.2228444218635559,110120:0.21789270639419556,121558:0.2170887589454651,120729:0.21672362089157104,111767:0.21340137720108032,101570:0.21161925792694092,121662:0.20944488048553467,109630:0.20760905742645264,93288:0.20647978782653809,98903:0.20381641387939453',
#  '110612:110604|107819:-0.0411914587020874,107820:-0.0411914587020874,102595:-0.07190155982971191,100493:-0.10882246494293213,89338:-0.10942673683166504,97167:-0.11775755882263184,101244:-0.1261887550354004,105084:-0.1313539743423462,119049:-0.13194036483764648,119048:-0.13272356986999512,116199:-0.13348710536956787,122166:-0.1340346336364746,101845:-0.13536548614501953,100544:-0.13630890846252441,122649:-0.1379638910293579,122650:-0.1379638910293579,104657:-0.13796734809875488,109104:-0.14066290855407715,106798:-0.1470355987548828,113225:-0.14842522144317627,92613:-0.15186333656311035,107893:-0.15245211124420166,103786:-0.1532607078552246,111617:-0.1539008617401123,93914:-0.1580195426940918,94544:-0.15818965435028076,101596:-0.15903174877166748,98276:-0.160040020942688,96736:-0.16102564334869385',
#  '116738:116938,117027|116938:0.29470354318618774,117027:0.23142880201339722,116229:0.08539712429046631,107237:0.0763479471206665,92166:0.06746912002563477,92173:0.06689238548278809,106729:0.06681126356124878,101552:0.06040847301483154,100325:0.04789161682128906,96735:0.04462558031082153,68248:0.043171226978302,104421:0.03854447603225708,92823:0.038492441177368164,112377:0.037005722522735596,88225:0.03583639860153198,114977:0.03345084190368652,115767:0.031406939029693604,92480:0.03131526708602905,122894:0.03056389093399048,103575:0.030197083950042725,106234:0.029449403285980225,109794:0.028332233428955078,105278:0.025812745094299316,111969:0.022736012935638428,106733:0.019859731197357178,114049:0.018015384674072266,97894:0.017704427242279053,93220:0.017507553100585938,94749:0.016133368015289307']

# %% [markdown]
# #### Exporting the result

# %%
EXPORT_RANK_PATH = os.path.join(DIR, 'exported_rank_{}.txt'.format(METHOD))

# %%
with open(EXPORT_RANK_PATH, 'w') as file_out:
    for row in exported_rank:
        file_out.write(row + "\n")

# %%
report = experiment.evaluation.evaluate(EXPORT_RANK_PATH)
report
# Out:
# {'1 - recall_at_5': 0.33,
#  '2 - recall_at_10': 0.38,
#  '3 - recall_at_15': 0.43,
#  '4 - recall_at_20': 0.46,
#  '5 - recall_at_25': 0.49}

# %% [markdown]
# #### Saving model

# %%
model.save_model(os.path.join('modelos', SAVE_PATH_FEATURE.replace('@number_of_epochs@', str(max_epochs)) + '.bin'))
