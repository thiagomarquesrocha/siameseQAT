# %% [markdown]
# # Bug triage with Deep Learning - Fasttext

# %%
from __future__ import print_function, division

# %%
import fasttext
import re
import numpy as np
import pandas as pd

import os
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
    
# %matplotlib inline

# %%
from methods.baseline import Baseline
from methods.experiments import Experiment
from methods.evaluation import Evaluation
from methods.retrieval import Retrieval
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Configurações Globais

# %%
MAX_SEQUENCE_LENGTH_T = 100 # 40
MAX_SEQUENCE_LENGTH_D = 500 # 200
EMBEDDING_DIM = 300
MAX_NB_WORDS = 20000

# %% [markdown]
# ### Parse bugs preproprecessed

# %%
# Domain to use
DOMAIN = 'netbeans'
METHOD = 'fasttext'
# Dataset paths
DIR = 'data/processed/{}'.format(DOMAIN)
DIR_PAIRS = 'data/normalized/{}'.format(DOMAIN)
DATASET = os.path.join('data/normalized/{}'.format(DOMAIN), '{}.csv'.format(DOMAIN))
# Path embeddings
EMBED_DIR='data/embed'
# Save model
SAVE_PATH = 'propose_feature@number_of_epochs@epochs_64batch({})'.format(DOMAIN)
SAVE_PATH_FEATURE = 'propose_feature_@number_of_epochs@epochs_64batch({})'.format(DOMAIN)

# Test bugs
PATH_TEST = 'data/processed/{}/test.txt'.format(DOMAIN)

# Extract CORPUs
EXTRACT_CORPUS = False

# %% [markdown]
# ## Auxiliary methods

# %%
baseline = Baseline(DIR, DATASET, MAX_SEQUENCE_LENGTH_T, MAX_SEQUENCE_LENGTH_D)
evaluation = Evaluation(verbose=0)
retrieval = Retrieval()
experiment = Experiment(baseline, evaluation)

# %% [markdown]
# #### Creating buckets and initialize the retrieval method

# %%
experiment.set_retrieval(retrieval, baseline, DOMAIN)
# Out:
# Creating the buckets...
# HBox(children=(IntProgress(value=0, max=180483), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=36232), HTML(value='')))

# %% [markdown]
# #### Loading bug ids in memory

# %%
experiment.load_ids()
len(baseline.bug_ids)
# Out:
# Reading bug ids
# 216715

# %% [markdown]
# #### Dicionário de títulos e descrições

# %%
# %%time

experiment.load_bugs()
len(baseline.sentence_dict)
# Out:
# HBox(children=(IntProgress(value=0, max=216715), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# CPU times: user 1min 28s, sys: 8.83 s, total: 1min 36s
# Wall time: 2min 5s

# %% [markdown]
# #### Get buckets for each issue

# %%
verbose = 0
issues_by_buckets = experiment.get_buckets_for_bugs()
# Out:
# HBox(children=(IntProgress(value=0, max=180483), HTML(value='')))

# %% [markdown]
# #### Prepare dataset

# %%
experiment.prepare_dataset(issues_by_buckets)
# Out:
# Reading train data
# Reading bug ids

# %% [markdown]
# #### Creating the queries to test

# %%
# Read and create the test queries duplicate
experiment.create_queries()
# Out:
# Reading queries from baseline.

# %% [markdown]
# #### Bugs train

# %%
bugs_train_ids = []
for bugs in experiment.baseline.train_data:
    bugs_train_ids.append(bugs[0])
    bugs_train_ids.append(bugs[1])

# %% [markdown]
# #### Corpus

# %%
lines_title = [baseline.bug_set[bug_id]['title'] for bug_id in bugs_train_ids]
lines_desc = [baseline.bug_set[bug_id]['description'] for bug_id in bugs_train_ids]

lines = []
for title, desc in zip(lines_title, lines_desc):
    lines.append(title)
    lines.append(desc)

# %%
len(lines)
# Out:
# 348728

# %% [markdown]
# #### Exporting corpus to .txt

# %%
EXPORT_PATH = os.path.join(DIR, 'corpus_fasttext_train.txt')
print(EXPORT_PATH)
with open(EXPORT_PATH, 'w') as f:
    for row in lines:
        f.write("{}\n".format(str(row).encode("utf-8")))
# Out:
# data/processed/netbeans/corpus_fasttext_train.txt

# %% [markdown]
# #### Train the method

# %%
# %%time

import os

cpu = os.cpu_count() - 1

# Skipgram model :
model = fasttext.train_unsupervised(EXPORT_PATH, 
                                    model='cbow', 
                                    minCount=1,
                                    neg=10,
                                    wordNgrams=3,
                                    epoch=15, 
                                    dim=300, 
                                    loss='hs', 
                                    thread=cpu, 
                                    verbose=2)
# Out:
# CPU times: user 6h 8min 33s, sys: 9.1 s, total: 6h 8min 42s
# Wall time: 52min 46s

# %% [markdown]
# #### Rank@25

# %%
recall, exported_rank = experiment.evaluate_validation_test(retrieval, verbose, model, issues_by_buckets, method=METHOD)
"recall@25 last epoch:", recall
# Out:
# ('recall@25 last epoch:', 0.24)

# %% [markdown]
# ### Retrieval evaluation

# %%
print("Total of queries:", len(retrieval.test))
# Out:
# Total of queries: 7164

# %%
exported_rank[:20]
# Out:
#  '131085:131082|131082:1.0,76311:0.46291589736938477,79830:0.4619107246398926,13038:0.35200226306915283,11617:0.3499665856361389,23586:0.3453083038330078,22011:0.34459662437438965,135177:0.3421138525009155,17633:0.3307344913482666,47408:0.3254539370536804,47581:0.32464784383773804,107055:0.32273608446121216,160206:0.3213115334510803,11567:0.31849533319473267,219709:0.31652235984802246,131490:0.3155022859573364,13749:0.31205952167510986,126646:0.31137144565582275,51919:0.3087612986564636,215459:0.3052188754081726,12520:0.30473792552948,104665:0.30443835258483887,182678:0.30416375398635864,42620:0.30275672674179077,32240:0.30232173204421997',
#  '65910:63195|39637:0.33796876668930054,131835:0.3189545273780823,152051:0.30614417791366577,20493:0.30538076162338257,132829:0.3027500510215759,82958:0.2962125539779663,89382:0.2919864058494568,207149:0.287672221660614,70372:0.2854740023612976,153877:0.28317034244537354,43165:0.27800554037094116,136083:0.27749645709991455,123370:0.27648288011550903,203381:0.272713303565979,27109:0.2715185880661011,208553:0.2709806561470032,41796:0.26595014333724976,68782:0.26547569036483765,76741:0.26533544063568115,168106:0.2644861936569214,165262:0.2580455541610718,139809:0.25729888677597046,110232:0.2554590106010437,208203:0.2547251582145691,69810:0.25417375564575195',
#  '67772:63195|64364:0.743628978729248,66324:0.6659868657588959,67718:0.6548181772232056,63195:0.6459205150604248,70776:0.6250217854976654,49840:0.6191058158874512,65463:0.6183776557445526,75032:0.6051369607448578,46466:0.6042433679103851,49897:0.5550551116466522,48621:0.5479531288146973,68118:0.547625333070755,64941:0.5474924147129059,46451:0.5397870540618896,77092:0.5380357503890991,61130:0.5362812280654907,101511:0.5325711071491241,65354:0.5303501784801483,40729:0.5249664485454559,43764:0.523451030254364,49900:0.5220164954662323,27049:0.5200574994087219,71744:0.5193856656551361,79009:0.5188058614730835,98130:0.517778754234314',
#  '65550:63195|64364:0.7739339470863342,66324:0.6780601739883423,67718:0.6638778448104858,63195:0.6627423465251923,49840:0.6589364111423492,70776:0.6506327390670776,75032:0.629806637763977,65463:0.6228480041027069,46466:0.6008365154266357,48621:0.590520828962326,46451:0.5694949924945831,98130:0.5648772120475769,68118:0.5582951009273529,49897:0.5575771629810333,43764:0.5476956963539124,79574:0.5454820692539215,64937:0.5453458428382874,49900:0.5410622656345367,117536:0.5409419536590576,65354:0.5406080782413483,27049:0.5388259887695312,61130:0.5382462739944458,17909:0.5332244038581848,123678:0.5327371954917908,77092:0.5312556028366089']

# %% [markdown]
# #### Exporting the result

# %%
EXPORT_RANK_PATH = os.path.join(DIR, 'exported_rank_{}.txt'.format(METHOD))

# %%
with open(EXPORT_RANK_PATH, 'w') as file_out:
    for row in exported_rank:
        file_out.write(row + "\n")

# %%
report = experiment.evaluation.evaluate(EXPORT_RANK_PATH)
report
# Out:
# {'1 - recall_at_5': 0.2,
#  '2 - recall_at_10': 0.21,
#  '3 - recall_at_15': 0.23,
#  '4 - recall_at_20': 0.24,
#  '5 - recall_at_25': 0.24}
