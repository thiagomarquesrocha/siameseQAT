# %% [markdown]
# # Bug triage with Deep Learning - Fasttext

# %%
from __future__ import print_function, division

# %%
import fasttext
import re
import numpy as np
import pandas as pd

import os
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
    
# %matplotlib inline

# %%
from methods.baseline import Baseline
from methods.experiments import Experiment
from methods.evaluation import Evaluation
from methods.retrieval import Retrieval
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Configurações Globais

# %%
MAX_SEQUENCE_LENGTH_T = 100 # 40
MAX_SEQUENCE_LENGTH_D = 500 # 200
EMBEDDING_DIM = 300
MAX_NB_WORDS = 20000

# %% [markdown]
# ### Parse bugs preproprecessed

# %%
# Domain to use
DOMAIN = 'openoffice'
METHOD = 'fasttext'
# Dataset paths
DIR = 'data/processed/{}'.format(DOMAIN)
DIR_PAIRS = 'data/normalized/{}'.format(DOMAIN)
DATASET = os.path.join('data/normalized/{}'.format(DOMAIN), '{}.csv'.format(DOMAIN))
# Path embeddings
EMBED_DIR='data/embed'
# Save model
SAVE_PATH_FEATURE = '{}_feature_@number_of_epochs@epochs_64batch({})'.format(METHOD, DOMAIN)

# Test bugs
PATH_TEST = 'data/processed/{}/test.txt'.format(DOMAIN)

# Extract CORPUs
EXTRACT_CORPUS = False

# %% [markdown]
# ## Auxiliary methods

# %%
baseline = Baseline(DIR, DATASET, MAX_SEQUENCE_LENGTH_T, MAX_SEQUENCE_LENGTH_D)
evaluation = Evaluation(verbose=0)
retrieval = Retrieval()
experiment = Experiment(baseline, evaluation)

# %% [markdown]
# #### Creating buckets and initialize the retrieval method

# %%
experiment.set_retrieval(retrieval, baseline, DOMAIN)
# Out:
# Creating the buckets...
# HBox(children=(IntProgress(value=0, max=83503), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=14567), HTML(value='')))

# %% [markdown]
# #### Loading bug ids in memory

# %%
experiment.load_ids()
len(baseline.bug_ids)
# Out:
# Reading bug ids
# 98070

# %% [markdown]
# #### Dicionário de títulos e descrições

# %%
# %%time

experiment.load_bugs()
len(baseline.sentence_dict)
# Out:
# HBox(children=(IntProgress(value=0, max=98070), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# CPU times: user 40.6 s, sys: 1.13 s, total: 41.7 s
# Wall time: 41.3 s

# %% [markdown]
# #### Get buckets for each issue

# %%
verbose = 0
issues_by_buckets = experiment.get_buckets_for_bugs()
# Out:
# HBox(children=(IntProgress(value=0, max=83503), HTML(value='')))

# %% [markdown]
# #### Prepare dataset

# %%
experiment.prepare_dataset(issues_by_buckets)
# Out:
# Reading train data
# Reading bug ids

# %% [markdown]
# #### Creating the queries to test

# %%
# Read and create the test queries duplicate
experiment.create_queries()
# Out:
# Reading queries from baseline.

# %% [markdown]
# #### Bugs train

# %%
bugs_train_ids = []
for bugs in experiment.baseline.train_data:
    bugs_train_ids.append(bugs[0])
    bugs_train_ids.append(bugs[1])

# %% [markdown]
# #### Corpus

# %%
lines_title = [baseline.bug_set[bug_id]['title'] for bug_id in bugs_train_ids]
lines_desc = [baseline.bug_set[bug_id]['description'] for bug_id in bugs_train_ids]

lines = []
for title, desc in zip(lines_title, lines_desc):
    lines.append(title)
    lines.append(desc)

# %%
len(lines)
# Out:
# 214960

# %% [markdown]
# #### Exporting corpus to .txt

# %%
EXPORT_PATH = os.path.join(DIR, 'corpus_fasttext_train.txt')
print(EXPORT_PATH)
with open(EXPORT_PATH, 'w') as f:
    for row in lines:
        f.write("{}\n".format(str(row).encode("utf-8")))
# Out:
# data/processed/openoffice/corpus_fasttext_train.txt

# %% [markdown]
# #### Train the method

# %%
# %%time

import os

cpu = os.cpu_count() - 1

max_epochs = 60

# Skipgram model :
model = fasttext.train_unsupervised(EXPORT_PATH, 
                                    model='cbow', 
                                    minCount=1,
                                    neg=12,
                                    wordNgrams=1,
                                    epoch=max_epochs, 
                                    dim=300, 
                                    loss='hs', 
                                    thread=cpu, 
                                    verbose=2)
# Out:
# CPU times: user 4h 52min 30s, sys: 8.78 s, total: 4h 52min 39s
# Wall time: 42min 5s

# %% [markdown]
# #### Rank@25

# %%
recall, exported_rank = experiment.evaluate_validation_test(retrieval, verbose, model, issues_by_buckets, method=METHOD)
"recall@25 last epoch:", recall
# Out:
# ('recall@25 last epoch:', 0.23)

# %% [markdown]
# ### Retrieval evaluation

# %%
print("Total of queries:", len(retrieval.test))
# Out:
# Total of queries: 3861

# %%
exported_rank[:20]
# Out:
# ['16384:15363|4537:0.5025347173213959,48071:0.49102187156677246,2880:0.4774143695831299,6464:0.47304999828338623,5560:0.4571218490600586,8967:0.4526106119155884,32175:0.4516299366950989,92817:0.4481218457221985,10613:0.4479129910469055,107914:0.4441019296646118,25140:0.44124460220336914,87901:0.4400675892829895,101725:0.4375605583190918,53845:0.435147225856781,5149:0.4260609745979309,1034:0.42392146587371826,12710:0.42252296209335327,58672:0.418052077293396,28625:0.4163869023323059,22519:0.4100836515426636,70692:0.4096079468727112,85426:0.4085348844528198,93583:0.40640389919281006,91015:0.40582120418548584,122149:0.4024706482887268',
#  
15363|4537:0.5025347173213959,48071:0.49102187156677246,2880:0.4774143695831299,6464:0.47304999828338623,5560:0.4571218490600586,8967:0.4526106119155884,32175:0.4516299366950989,92817:0.4481218457221985,10613:0.4479129910469055,107914:0.4441019296646118,25140:0.44124460220336914,87901:0.4400675892829895,101725:0.4375605583190918,53845:0.435147225856781,5149:0.4260609745979309,1034:0.42392146587371826,12710:0.42252296209335327,58672:0.418052077293396,28625:0.4163869023323059,22519:0.4100836515426636,70692:0.4096079468727112,85426:0.4085348844528198,93583:0.40640389919281006,91015:0.40582120418548584,122149:0.4024706482887268',
#  '14054:15363|18486:0.39603734016418457,7998:0.3507724404335022,4366:0.34595370292663574,42768:0.3428046703338623,1940:0.33861780166625977,4726:0.3242548108100891,50019:0.3218801021575928,24521:0.29925233125686646,4502:0.298894464969635,120045:0.2959124445915222,18468:0.2927889823913574,19911:0.2921626567840576,23220:0.2821483016014099,108035:0.28200334310531616,58286:0.2792794704437256,255:0.27817147970199585,116162:0.27773022651672363,12788:0.27548402547836304,1872:0.27491235733032227,23855:0.2722010612487793,16410:0.2712485194206238,2150:0.26859211921691895,25706:0.26787906885147095,43146:0.26358407735824585,89095:0.263419508934021',
#  '16394:15363|4537:0.5025347173213959,48071:0.49102187156677246,2880:0.4774143695831299,6464:0.47304999828338623,5560:0.4571218490600586,8967:0.4526106119155884,32175:0.4516299366950989,92817:0.4481218457221985,10613:0.4479129910469055,107914:0.4441019296646118,25140:0.44124460220336914,87901:0.4400675892829895,101725:0.4375605583190918,53845:0.435147225856781,5149:0.4260609745979309,1034:0.42392146587371826,12710:0.42252296209335327,58672:0.418052077293396,28625:0.4163869023323059,22519:0.4100836515426636,70692:0.4096079468727112,85426:0.4085348844528198,93583:0.40640389919281006,91015:0.40582120418548584,122149:0.4024706482887268',
#  '16379:15363|4537:0.5025347173213959,48071:0.49102187156677246,2880:0.4774143695831299,6464:0.47304999828338623,5560:0.4571218490600586,8967:0.4526106119155884,32175:0.4516299366950989,92817:0.4481218457221985,10613:0.4479129910469055,107914:0.4441019296646118,25140:0.44124460220336914,87901:0.4400675892829895,101725:0.4375605583190918,53845:0.435147225856781,5149:0.4260609745979309,1034:0.42392146587371826,12710:0.42252296209335327,58672:0.418052077293396,28625:0.4163869023323059,22519:0.4100836515426636,70692:0.4096079468727112,85426:0.4085348844528198,93583:0.40640389919281006,91015:0.40582120418548584,122149:0.4024706482887268',
#  '14604:15363|12510:0.5464937090873718,28625:0.48765021562576294,92817:0.46548765897750854,74609:0.4652732014656067,76405:0.45791661739349365,122149:0.4288351535797119,106833:0.4237746000289917,91015:0.42301076650619507,76067:0.42263466119766235,109284:0.41643524169921875,11491:0.41592323780059814,53845:0.4156246781349182,58672:0.4143673777580261,4366:0.41348743438720703,48454:0.4106852412223816,15646:0.40918707847595215,76678:0.40850967168807983,48071:0.40310829877853394,63867:0.4018669128417969,113631:0.4010921120643616,4726:0.3977203965187073,47544:0.3975883722305298,15799:0.39673227071762085,12087:0.3960459232330322,88376:0.3927045464515686',
#  '16395:15363|4537:0.5025347173213959,48071:0.49102187156677246,2880:0.4774143695831299,6464:0.47304999828338623,5560:0.4571218490600586,8967:0.4526106119155884,32175:0.4516299366950989,92817:0.4481218457221985,10613:0.4479129910469055,107914:0.4441019296646118,25140:0.44124460220336914,87901:0.4400675892829895,101725:0.4375605583190918,53845:0.435147225856781,5149:0.4260609745979309,1034:0.42392146587371826,12710:0.42252296209335327,58672:0.418052077293396,28625:0.4163869023323059,22519:0.4100836515426636,70692:0.4096079468727112,85426:0.4085348844528198,93583:0.40640389919281006,91015:0.40582120418548584,122149:0.4024706482887268',
#  '16390:15363|4537:0.5025347173213959,48071:0.49102187156677246,2880:0.4774143695831299,6464:0.47304999828338623,5560:0.4571218490600586,8967:0.4526106119155884,32175:0.4516299366950989,92817:0.4481218457221985,10613:0.4479129910469055,107914:0.4441019296646118,25140:0.44124460220336914,87901:0.4400675892829895,101725:0.4375605583190918,53845:0.435147225856781,5149:0.4260609745979309,1034:0.42392146587371826,12710:0.42252296209335327,58672:0.418052077293396,28625:0.4163869023323059,22519:0.4100836515426636,70692:0.4096079468727112,85426:0.4085348844528198,93583:0.40640389919281006,91015:0.40582120418548584,122149:0.4024706482887268',
#  '8184:3724|66598:0.3293547034263611,65690:0.31042003631591797,29408:0.30749428272247314,22575:0.3052899241447449,42339:0.30141425132751465,69633:0.30112308263778687,4874:0.2985101342201233,26821:0.2902272939682007,15342:0.2891048192977905,21299:0.28673475980758667,58672:0.2852919101715088,56806:0.28476035594940186,67136:0.28421276807785034,55714:0.28190088272094727,9709:0.2818455100059509,20698:0.27851516008377075,4650:0.26701611280441284,99822:0.26630812883377075,31607:0.2660013437271118,24271:0.2654114365577698,48480:0.26479583978652954,83611:0.26240450143814087,9081:0.26118314266204834,12936:0.2610916495323181,90071:0.25985151529312134']

# %% [markdown]
# #### Exporting the result

# %%
EXPORT_RANK_PATH = os.path.join(DIR, 'exported_rank_{}.txt'.format(METHOD))

# %%
with open(EXPORT_RANK_PATH, 'w') as file_out:
    for row in exported_rank:
        file_out.write(row + "\n")

# %%
report = experiment.evaluation.evaluate(EXPORT_RANK_PATH)
report
# Out:
# {'1 - recall_at_5': 0.15,
#  '2 - recall_at_10': 0.19,
#  '3 - recall_at_15': 0.2,
#  '4 - recall_at_20': 0.22,
#  '5 - recall_at_25': 0.23}

# %% [markdown]
# #### Saving model

# %%
model.save_model(os.path.join('modelos', SAVE_PATH_FEATURE.replace('@number_of_epochs@', str(max_epochs)) + '.bin'))
